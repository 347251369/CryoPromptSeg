# %%
from models.dpa_p2pnet import build_model
import glob
from mmengine.config import Config

cfg = Config.fromfile('config/cryoPoint.py')

model = build_model(cfg)
model_without_ddp = model
# 检查 model 和 model_without_ddp 是否指向同一个对象
if model is model_without_ddp:
    print("model 和 model_without_ddp 指向同一个对象")
else:
    print("model 和 model_without_ddp 指向不同的对象")
# Out:
# model 和 model_without_ddp 指向同一个对象

# %%
  # 冻结模型的所有参数
for params in model_without_ddp.parameters():
    params.requires_grad = False

# %%
for name, param in model.named_parameters():

    if param.requires_grad:
        print(f"Parameter '{name}' is trainable.")
    else:
        # print(f"Parameter '{name}' is frozen.")
        continue
      # 没输出说明冻结所有参数

# %%
denoise_params = []
for params in model_without_ddp.backbone.unet_encoder.parameters():
    params.requires_grad = True
    denoise_params += [params]
for params in model_without_ddp.backbone.unet_decoder.parameters():
    params.requires_grad = True
    denoise_params += [params]
for params in model_without_ddp.backbone.feature_selection.parameters():
    params.requires_grad = True
    denoise_params += [params]

seg_params = []
for params in model_without_ddp.backbone.backbone.parameters():
    params.requires_grad = True
    seg_params += [params]
for params in model_without_ddp.backbone.neck.parameters():
    params.requires_grad = True
    seg_params += [params]
for params in model_without_ddp.backbone.neck1.parameters():
    params.requires_grad = True
    seg_params += [params]
for params in model_without_ddp.backbone.feature_selection.parameters():
    params.requires_grad = True
    seg_params += [params]
for params in model_without_ddp.deform_layer.parameters():
    params.requires_grad = True
    seg_params += [params]
for params in model_without_ddp.reg_head.parameters():
    params.requires_grad = True
    seg_params += [params]
for params in model_without_ddp.cls_head.parameters():
    params.requires_grad = True
    seg_params += [params]
for params in model_without_ddp.conv.parameters():
    params.requires_grad = True
    seg_params += [params]
for params in model_without_ddp.mask_head.parameters():
    params.requires_grad = True
    seg_params += [params]

# %%
for name, param in model.named_parameters():
    if param.requires_grad:
        # print(f"Parameter '{name}' is trainable.")
        continue
    else:
        print(f"Parameter '{name}' is frozen.")
    # 没输出说明全都解冻

# %%
# 打印每一层的参数
for name, param in model.named_parameters():
    # if param.requires_grad:
    if "feature_selection"  in name and  "leakyunit_u_fpn" not in name and "leakyunit_fpn_u" not in name:
      
      print(f"Layer: {name}, Shape: {param.shape}")

# %%
for name, param in model.named_parameters():
    # print(f"Layer: {name}, Shape: {param.shape}")
    if name == 'deform_layer.layers.0.weight':
        print(f"Layer: {name}, Shape: {param}")
# Out:
# Layer: deform_layer.layers.0.weight, Shape: Parameter containing:
# tensor([[ 0.0391, -0.0611,  0.0527,  ...,  0.0382, -0.0605,  0.0706],
#         [ 0.0488,  0.0299, -0.0435,  ..., -0.0055, -0.0340, -0.0035],
#         [ 0.0626, -0.0202,  0.0211,  ...,  0.0347, -0.0071, -0.0414],
#         ...,
#         [-0.0622,  0.0344,  0.0196,  ...,  0.0495,  0.0393,  0.0497],
#         [ 0.0242,  0.0107, -0.0018,  ..., -0.0302,  0.0157, -0.0430],
#         [-0.0146,  0.0494,  0.0103,  ..., -0.0149,  0.0449, -0.0356]],
#        requires_grad=True)

# %%
import torch
dir_checkpoint='checkpoint/test1/latest.pth'
checkpoint = torch.load(dir_checkpoint )
print(checkpoint.keys())

# # 提取 state_dict
state_dict = checkpoint['model']  # 如果键是 'state_dict'

# 查看每一层的参数
for name, param in state_dict.items():
    # print(f"Layer: {name}, Shape: {param}")
      # if name == 'deform_layer.layers.0.weight':
        print(f"Layer: {name}, Shape: {param.shape}")
# Out:
# dict_keys(['model', 'optimizer', 'f1', 'epoch', 'args'])
# Layer: backbone.backbone.stem.0.weight, Shape: torch.Size([96, 3, 4, 4])
# Layer: backbone.backbone.stem.0.bias, Shape: torch.Size([96])
# Layer: backbone.backbone.stem.1.weight, Shape: torch.Size([96])
# Layer: backbone.backbone.stem.1.bias, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.0.gamma, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.0.conv_dw.weight, Shape: torch.Size([96, 1, 7, 7])
# Layer: backbone.backbone.stages.0.blocks.0.conv_dw.bias, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.0.norm.weight, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.0.norm.bias, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.0.mlp.fc1.weight, Shape: torch.Size([384, 96])
# Layer: backbone.backbone.stages.0.blocks.0.mlp.fc1.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.0.blocks.0.mlp.fc2.weight, Shape: torch.Size([96, 384])
# Layer: backbone.backbone.stages.0.blocks.0.mlp.fc2.bias, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.1.gamma, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.1.conv_dw.weight, Shape: torch.Size([96, 1, 7, 7])
# Layer: backbone.backbone.stages.0.blocks.1.conv_dw.bias, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.1.norm.weight, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.1.norm.bias, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.1.mlp.fc1.weight, Shape: torch.Size([384, 96])
# Layer: backbone.backbone.stages.0.blocks.1.mlp.fc1.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.0.blocks.1.mlp.fc2.weight, Shape: torch.Size([96, 384])
# Layer: backbone.backbone.stages.0.blocks.1.mlp.fc2.bias, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.2.gamma, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.2.conv_dw.weight, Shape: torch.Size([96, 1, 7, 7])
# Layer: backbone.backbone.stages.0.blocks.2.conv_dw.bias, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.2.norm.weight, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.2.norm.bias, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.0.blocks.2.mlp.fc1.weight, Shape: torch.Size([384, 96])
# Layer: backbone.backbone.stages.0.blocks.2.mlp.fc1.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.0.blocks.2.mlp.fc2.weight, Shape: torch.Size([96, 384])
# Layer: backbone.backbone.stages.0.blocks.2.mlp.fc2.bias, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.1.downsample.0.weight, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.1.downsample.0.bias, Shape: torch.Size([96])
# Layer: backbone.backbone.stages.1.downsample.1.weight, Shape: torch.Size([192, 96, 2, 2])
# Layer: backbone.backbone.stages.1.downsample.1.bias, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.0.gamma, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.0.conv_dw.weight, Shape: torch.Size([192, 1, 7, 7])
# Layer: backbone.backbone.stages.1.blocks.0.conv_dw.bias, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.0.norm.weight, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.0.norm.bias, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.0.mlp.fc1.weight, Shape: torch.Size([768, 192])
# Layer: backbone.backbone.stages.1.blocks.0.mlp.fc1.bias, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.1.blocks.0.mlp.fc2.weight, Shape: torch.Size([192, 768])
# Layer: backbone.backbone.stages.1.blocks.0.mlp.fc2.bias, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.1.gamma, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.1.conv_dw.weight, Shape: torch.Size([192, 1, 7, 7])
# Layer: backbone.backbone.stages.1.blocks.1.conv_dw.bias, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.1.norm.weight, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.1.norm.bias, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.1.mlp.fc1.weight, Shape: torch.Size([768, 192])
# Layer: backbone.backbone.stages.1.blocks.1.mlp.fc1.bias, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.1.blocks.1.mlp.fc2.weight, Shape: torch.Size([192, 768])
# Layer: backbone.backbone.stages.1.blocks.1.mlp.fc2.bias, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.2.gamma, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.2.conv_dw.weight, Shape: torch.Size([192, 1, 7, 7])
# Layer: backbone.backbone.stages.1.blocks.2.conv_dw.bias, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.2.norm.weight, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.2.norm.bias, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.1.blocks.2.mlp.fc1.weight, Shape: torch.Size([768, 192])
# Layer: backbone.backbone.stages.1.blocks.2.mlp.fc1.bias, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.1.blocks.2.mlp.fc2.weight, Shape: torch.Size([192, 768])
# Layer: backbone.backbone.stages.1.blocks.2.mlp.fc2.bias, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.2.downsample.0.weight, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.2.downsample.0.bias, Shape: torch.Size([192])
# Layer: backbone.backbone.stages.2.downsample.1.weight, Shape: torch.Size([384, 192, 2, 2])
# Layer: backbone.backbone.stages.2.downsample.1.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.0.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.0.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.0.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.0.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.0.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.0.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.0.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.0.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.0.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.1.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.1.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.1.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.1.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.1.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.1.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.1.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.1.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.1.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.2.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.2.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.2.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.2.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.2.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.2.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.2.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.2.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.2.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.3.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.3.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.3.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.3.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.3.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.3.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.3.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.3.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.3.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.4.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.4.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.4.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.4.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.4.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.4.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.4.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.4.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.4.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.5.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.5.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.5.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.5.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.5.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.5.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.5.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.5.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.5.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.6.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.6.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.6.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.6.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.6.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.6.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.6.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.6.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.6.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.7.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.7.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.7.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.7.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.7.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.7.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.7.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.7.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.7.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.8.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.8.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.8.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.8.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.8.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.8.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.8.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.8.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.8.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.9.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.9.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.9.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.9.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.9.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.9.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.9.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.9.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.9.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.10.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.10.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.10.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.10.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.10.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.10.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.10.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.10.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.10.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.11.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.11.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.11.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.11.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.11.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.11.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.11.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.11.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.11.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.12.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.12.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.12.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.12.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.12.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.12.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.12.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.12.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.12.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.13.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.13.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.13.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.13.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.13.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.13.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.13.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.13.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.13.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.14.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.14.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.14.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.14.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.14.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.14.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.14.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.14.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.14.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.15.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.15.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.15.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.15.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.15.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.15.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.15.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.15.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.15.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.16.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.16.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.16.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.16.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.16.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.16.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.16.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.16.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.16.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.17.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.17.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.17.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.17.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.17.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.17.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.17.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.17.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.17.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.18.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.18.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.18.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.18.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.18.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.18.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.18.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.18.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.18.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.19.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.19.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.19.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.19.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.19.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.19.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.19.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.19.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.19.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.20.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.20.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.20.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.20.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.20.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.20.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.20.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.20.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.20.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.21.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.21.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.21.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.21.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.21.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.21.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.21.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.21.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.21.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.22.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.22.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.22.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.22.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.22.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.22.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.22.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.22.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.22.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.23.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.23.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.23.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.23.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.23.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.23.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.23.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.23.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.23.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.24.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.24.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.24.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.24.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.24.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.24.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.24.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.24.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.24.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.25.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.25.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.25.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.25.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.25.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.25.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.25.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.25.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.25.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.26.gamma, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.26.conv_dw.weight, Shape: torch.Size([384, 1, 7, 7])
# Layer: backbone.backbone.stages.2.blocks.26.conv_dw.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.26.norm.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.26.norm.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.2.blocks.26.mlp.fc1.weight, Shape: torch.Size([1536, 384])
# Layer: backbone.backbone.stages.2.blocks.26.mlp.fc1.bias, Shape: torch.Size([1536])
# Layer: backbone.backbone.stages.2.blocks.26.mlp.fc2.weight, Shape: torch.Size([384, 1536])
# Layer: backbone.backbone.stages.2.blocks.26.mlp.fc2.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.3.downsample.0.weight, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.3.downsample.0.bias, Shape: torch.Size([384])
# Layer: backbone.backbone.stages.3.downsample.1.weight, Shape: torch.Size([768, 384, 2, 2])
# Layer: backbone.backbone.stages.3.downsample.1.bias, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.0.gamma, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.0.conv_dw.weight, Shape: torch.Size([768, 1, 7, 7])
# Layer: backbone.backbone.stages.3.blocks.0.conv_dw.bias, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.0.norm.weight, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.0.norm.bias, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.0.mlp.fc1.weight, Shape: torch.Size([3072, 768])
# Layer: backbone.backbone.stages.3.blocks.0.mlp.fc1.bias, Shape: torch.Size([3072])
# Layer: backbone.backbone.stages.3.blocks.0.mlp.fc2.weight, Shape: torch.Size([768, 3072])
# Layer: backbone.backbone.stages.3.blocks.0.mlp.fc2.bias, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.1.gamma, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.1.conv_dw.weight, Shape: torch.Size([768, 1, 7, 7])
# Layer: backbone.backbone.stages.3.blocks.1.conv_dw.bias, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.1.norm.weight, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.1.norm.bias, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.1.mlp.fc1.weight, Shape: torch.Size([3072, 768])
# Layer: backbone.backbone.stages.3.blocks.1.mlp.fc1.bias, Shape: torch.Size([3072])
# Layer: backbone.backbone.stages.3.blocks.1.mlp.fc2.weight, Shape: torch.Size([768, 3072])
# Layer: backbone.backbone.stages.3.blocks.1.mlp.fc2.bias, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.2.gamma, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.2.conv_dw.weight, Shape: torch.Size([768, 1, 7, 7])
# Layer: backbone.backbone.stages.3.blocks.2.conv_dw.bias, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.2.norm.weight, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.2.norm.bias, Shape: torch.Size([768])
# Layer: backbone.backbone.stages.3.blocks.2.mlp.fc1.weight, Shape: torch.Size([3072, 768])
# Layer: backbone.backbone.stages.3.blocks.2.mlp.fc1.bias, Shape: torch.Size([3072])
# Layer: backbone.backbone.stages.3.blocks.2.mlp.fc2.weight, Shape: torch.Size([768, 3072])
# Layer: backbone.backbone.stages.3.blocks.2.mlp.fc2.bias, Shape: torch.Size([768])
# Layer: backbone.neck.lateral_convs.0.conv.weight, Shape: torch.Size([256, 96, 1, 1])
# Layer: backbone.neck.lateral_convs.0.conv.bias, Shape: torch.Size([256])
# Layer: backbone.neck.lateral_convs.1.conv.weight, Shape: torch.Size([256, 192, 1, 1])
# Layer: backbone.neck.lateral_convs.1.conv.bias, Shape: torch.Size([256])
# Layer: backbone.neck.lateral_convs.2.conv.weight, Shape: torch.Size([256, 384, 1, 1])
# Layer: backbone.neck.lateral_convs.2.conv.bias, Shape: torch.Size([256])
# Layer: backbone.neck.lateral_convs.3.conv.weight, Shape: torch.Size([256, 768, 1, 1])
# Layer: backbone.neck.lateral_convs.3.conv.bias, Shape: torch.Size([256])
# Layer: backbone.neck.fpn_convs.0.conv.weight, Shape: torch.Size([256, 256, 3, 3])
# Layer: backbone.neck.fpn_convs.0.conv.bias, Shape: torch.Size([256])
# Layer: backbone.neck.fpn_convs.1.conv.weight, Shape: torch.Size([256, 256, 3, 3])
# Layer: backbone.neck.fpn_convs.1.conv.bias, Shape: torch.Size([256])
# Layer: backbone.neck.fpn_convs.2.conv.weight, Shape: torch.Size([256, 256, 3, 3])
# Layer: backbone.neck.fpn_convs.2.conv.bias, Shape: torch.Size([256])
# Layer: backbone.neck.fpn_convs.3.conv.weight, Shape: torch.Size([256, 256, 3, 3])
# Layer: backbone.neck.fpn_convs.3.conv.bias, Shape: torch.Size([256])
# Layer: backbone.neck1.lateral_convs.0.conv.weight, Shape: torch.Size([256, 96, 1, 1])
# Layer: backbone.neck1.lateral_convs.0.conv.bias, Shape: torch.Size([256])
# Layer: backbone.neck1.lateral_convs.1.conv.weight, Shape: torch.Size([256, 192, 1, 1])
# Layer: backbone.neck1.lateral_convs.1.conv.bias, Shape: torch.Size([256])
# Layer: backbone.neck1.lateral_convs.2.conv.weight, Shape: torch.Size([256, 384, 1, 1])
# Layer: backbone.neck1.lateral_convs.2.conv.bias, Shape: torch.Size([256])
# Layer: backbone.neck1.lateral_convs.3.conv.weight, Shape: torch.Size([256, 768, 1, 1])
# Layer: backbone.neck1.lateral_convs.3.conv.bias, Shape: torch.Size([256])
# Layer: backbone.neck1.fpn_convs.0.conv.weight, Shape: torch.Size([256, 256, 3, 3])
# Layer: backbone.neck1.fpn_convs.0.conv.bias, Shape: torch.Size([256])
# Layer: deform_layer.layers.0.weight, Shape: torch.Size([256, 256])
# Layer: deform_layer.layers.0.bias, Shape: torch.Size([256])
# Layer: deform_layer.layers.3.weight, Shape: torch.Size([2, 256])
# Layer: deform_layer.layers.3.bias, Shape: torch.Size([2])
# Layer: reg_head.layers.0.weight, Shape: torch.Size([256, 256])
# Layer: reg_head.layers.0.bias, Shape: torch.Size([256])
# Layer: reg_head.layers.3.weight, Shape: torch.Size([2, 256])
# Layer: reg_head.layers.3.bias, Shape: torch.Size([2])
# Layer: cls_head.layers.0.weight, Shape: torch.Size([256, 256])
# Layer: cls_head.layers.0.bias, Shape: torch.Size([256])
# Layer: cls_head.layers.3.weight, Shape: torch.Size([2, 256])
# Layer: cls_head.layers.3.bias, Shape: torch.Size([2])
# Layer: conv.weight, Shape: torch.Size([256, 1024, 3, 3])
# Layer: conv.bias, Shape: torch.Size([256])
# Layer: mask_head.0.weight, Shape: torch.Size([256, 256, 3, 3])
# Layer: mask_head.0.bias, Shape: torch.Size([256])
# Layer: mask_head.1.weight, Shape: torch.Size([256])
# Layer: mask_head.1.bias, Shape: torch.Size([256])
# Layer: mask_head.1.running_mean, Shape: torch.Size([256])
# Layer: mask_head.1.running_var, Shape: torch.Size([256])
# Layer: mask_head.1.num_batches_tracked, Shape: torch.Size([])
# Layer: mask_head.3.weight, Shape: torch.Size([1, 256, 1, 1])
# Layer: mask_head.3.bias, Shape: torch.Size([1])

# %%
import torch
unet_checkpoint='pretrained/unet_L2_v0.2.2.sav'
ucheckpoint = torch.load(unet_checkpoint )

print(ucheckpoint.keys())

# # 查看每一层的参数
for name, param in ucheckpoint.items():
  # if "backbone.backbone" not in name:
    if name == 'dec5.0.weight':
      print(f"Layer: {name}, Shape: {param}")
# Out:
# odict_keys(['enc1.0.weight', 'enc1.0.bias', 'enc2.0.weight', 'enc2.0.bias', 'enc3.0.weight', 'enc3.0.bias', 'enc4.0.weight', 'enc4.0.bias', 'enc5.0.weight', 'enc5.0.bias', 'enc6.0.weight', 'enc6.0.bias', 'dec5.0.weight', 'dec5.0.bias', 'dec5.2.weight', 'dec5.2.bias', 'dec4.0.weight', 'dec4.0.bias', 'dec4.2.weight', 'dec4.2.bias', 'dec3.0.weight', 'dec3.0.bias', 'dec3.2.weight', 'dec3.2.bias', 'dec2.0.weight', 'dec2.0.bias', 'dec2.2.weight', 'dec2.2.bias', 'dec1.0.weight', 'dec1.0.bias', 'dec1.2.weight', 'dec1.2.bias', 'dec1.4.weight', 'dec1.4.bias'])
# Layer: dec5.0.weight, Shape: tensor([[[[ 1.0222e-02,  2.9191e-02,  2.4678e-02],
#           [ 2.2373e-02, -1.3180e-02,  1.9336e-02],
#           [-2.1471e-02,  1.3956e-03,  2.4064e-02]],
#
#          [[ 2.6783e-03,  3.4265e-02,  2.3746e-02],
#           [ 4.2873e-02, -1.1728e-02, -1.5978e-02],
#           [ 2.5280e-04, -2.8526e-03, -1.7375e-02]],
#
#          [[-1.4609e-02, -1.2369e-02,  1.3339e-02],
#           [-3.1278e-02,  1.2187e-02, -1.6942e-02],
#           [-2.2846e-02, -2.2044e-02,  1.7317e-02]],
#
#          ...,
#
#          [[-2.4315e-02,  2.4656e-02,  2.7946e-02],
#           [-2.6727e-02,  1.8569e-02,  2.8729e-02],
#           [-1.1396e-02,  2.2902e-02,  3.1545e-02]],
#
#          [[-2.1918e-02, -2.0605e-02,  2.2728e-02],
#           [ 2.8235e-02, -1.9332e-02, -1.5089e-02],
#           [-2.0211e-02, -1.3377e-02,  2.9451e-02]],
#
#          [[ 4.4164e-03,  1.4385e-02, -2.9177e-02],
#           [-3.1478e-03, -3.3411e-02,  7.8873e-03],
#           [ 2.1615e-02,  1.2258e-02,  4.9559e-03]]],
#
#
#         [[[-3.8109e-02, -3.5831e-03,  1.8828e-02],
#           [-2.0970e-02,  4.1583e-03, -1.6774e-02],
#           [ 5.9647e-03, -5.8641e-03, -1.7510e-03]],
#
#          [[ 5.1382e-03,  4.2558e-02,  1.6336e-02],
#           [ 1.2526e-02,  2.4416e-02,  3.1658e-02],
#           [-8.9499e-03,  4.1728e-02,  4.4963e-03]],
#
#          [[ 2.8877e-02,  1.8925e-02, -1.5057e-02],
#           [ 2.1196e-02, -1.2908e-02, -1.0373e-02],
#           [ 8.4062e-03,  2.7032e-02,  1.2760e-02]],
#
#          ...,
#
#          [[ 2.2071e-02,  6.2485e-03,  1.0937e-02],
#           [-5.9434e-03,  1.6614e-02,  2.6867e-03],
#           [ 1.3849e-02,  1.3386e-02,  1.7717e-02]],
#
#          [[ 1.0585e-02,  6.7150e-03,  2.7850e-03],
#           [-5.9612e-03,  9.3033e-03, -3.7078e-03],
#           [ 1.7761e-02, -3.5121e-03,  1.1212e-02]],
#
#          [[-5.4810e-03,  6.7169e-04, -3.1242e-03],
#           [ 3.2386e-03,  1.7611e-02,  3.2145e-02],
#           [ 5.4716e-03, -1.3137e-02, -1.5544e-02]]],
#
#
#         [[[ 2.1432e-02, -1.5442e-02, -1.9416e-02],
#           [-1.0608e-02, -3.2277e-02, -3.1270e-02],
#           [-6.1853e-03, -2.8932e-02,  5.8869e-03]],
#
#          [[-8.1377e-04, -6.7393e-03,  4.0495e-02],
#           [ 3.3313e-02,  1.3806e-02,  2.8288e-03],
#           [ 1.8929e-02, -1.7521e-02,  3.1153e-02]],
#
#          [[-2.6534e-02, -3.7174e-02,  5.0938e-03],
#           [-9.8324e-03, -4.9618e-03, -1.5246e-02],
#           [ 1.3040e-02,  1.5277e-02, -2.2950e-02]],
#
#          ...,
#
#          [[ 1.0411e-02,  2.3462e-02, -5.1291e-03],
#           [-2.6336e-02, -1.4145e-02, -4.0625e-03],
#           [ 3.1307e-02, -2.9960e-02, -1.4637e-02]],
#
#          [[-2.3047e-02,  1.7584e-02,  7.8363e-03],
#           [-1.6492e-02, -1.3489e-02,  1.9988e-02],
#           [-2.0652e-03,  4.8527e-03, -4.0255e-03]],
#
#          [[-1.0513e-02, -1.7660e-02, -2.9891e-02],
#           [-7.4552e-03, -3.0971e-02, -1.3691e-02],
#           [-2.8436e-02, -2.6113e-02, -2.8645e-02]]],
#
#
#         ...,
#
#
#         [[[-8.8567e-03,  3.0854e-02,  3.3216e-02],
#           [ 3.2204e-02,  2.3866e-02,  9.9163e-03],
#           [ 3.8895e-02,  1.8298e-02, -7.7294e-03]],
#
#          [[ 1.9299e-02,  4.3311e-02, -5.8403e-03],
#           [-1.0497e-02, -1.1146e-02, -5.7730e-07],
#           [ 2.0279e-02, -1.4129e-03,  3.4592e-02]],
#
#          [[-5.1178e-03,  2.7871e-02, -2.2959e-02],
#           [ 2.5215e-02,  1.6163e-02, -7.1170e-03],
#           [ 3.7216e-04, -1.4487e-03,  6.2914e-03]],
#
#          ...,
#
#          [[-6.8599e-03, -2.3148e-02, -2.6847e-03],
#           [-1.7633e-02, -1.8155e-02,  2.0237e-02],
#           [ 3.4764e-03,  1.4275e-02, -4.0167e-04]],
#
#          [[-1.0451e-02,  2.4155e-02, -1.0313e-02],
#           [-7.6438e-04, -1.8946e-02,  3.1703e-02],
#           [ 3.5458e-02,  5.7947e-03, -6.3225e-03]],
#
#          [[-2.2343e-02, -1.9615e-02, -1.3633e-02],
#           [ 2.2498e-02, -1.0551e-02,  2.2021e-02],
#           [-4.1049e-03, -3.0143e-02, -1.9259e-02]]],
#
#
#         [[[ 6.0824e-03, -1.4216e-02, -3.2737e-02],
#           [-3.9481e-02,  2.1158e-02, -3.6686e-02],
#           [-2.6067e-02, -1.7184e-02,  1.2217e-03]],
#
#          [[ 3.3745e-02, -6.2469e-05, -2.0241e-02],
#           [-1.2864e-02, -1.5003e-03, -9.8152e-03],
#           [ 1.7864e-02,  2.8558e-02, -2.2672e-02]],
#
#          [[ 2.6104e-02, -3.3824e-02,  2.3726e-02],
#           [-1.1779e-02, -4.0169e-02, -2.4290e-02],
#           [-3.8779e-02, -1.2238e-02, -3.4570e-02]],
#
#          ...,
#
#          [[-1.8693e-03, -1.6553e-02, -9.0803e-03],
#           [-2.5396e-02, -3.8779e-02, -2.4947e-02],
#           [-3.7048e-02, -2.1219e-02, -2.4770e-02]],
#
#          [[-2.3725e-02, -4.7154e-03, -6.8087e-03],
#           [ 2.5853e-02, -3.1661e-02, -1.0406e-02],
#           [-3.2251e-02, -1.6509e-02,  4.9823e-03]],
#
#          [[-6.7898e-03,  1.6924e-02,  3.5784e-03],
#           [ 3.0747e-03, -2.1907e-02,  3.8640e-03],
#           [ 1.6788e-02,  3.2335e-02, -1.1666e-03]]],
#
#
#         [[[ 3.0782e-02,  1.3877e-02, -3.4916e-02],
#           [ 2.5875e-02,  2.7115e-02, -2.2675e-02],
#           [-2.6519e-02, -2.6714e-02,  2.4592e-02]],
#
#          [[ 1.0920e-02,  1.6504e-02, -2.0375e-02],
#           [-3.0797e-02,  1.3226e-02,  1.0699e-02],
#           [ 1.3747e-02,  3.7443e-03,  2.9483e-02]],
#
#          [[ 7.8225e-03, -1.2352e-02,  1.7730e-03],
#           [-2.2043e-02, -1.0713e-02,  2.9155e-02],
#           [ 2.6871e-02,  1.6653e-02,  1.6887e-02]],
#
#          ...,
#
#          [[ 1.3104e-02, -3.0978e-02,  6.1244e-03],
#           [-7.6694e-03,  1.5454e-04, -1.5417e-02],
#           [-9.5159e-03, -2.8162e-02,  1.9931e-02]],
#
#          [[-1.1504e-02,  3.0157e-02, -7.0409e-03],
#           [ 1.9703e-02,  3.3028e-02,  9.6348e-03],
#           [-2.1891e-02,  3.0123e-02, -1.3219e-02]],
#
#          [[-2.3031e-02,  7.3666e-03, -2.7738e-03],
#           [-6.1844e-03, -1.8661e-03,  1.7887e-02],
#           [ 2.3804e-02,  1.6048e-02,  3.4097e-02]]]])
