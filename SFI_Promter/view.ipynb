# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from skimage import io
import json
import glob

files='/root/autodl-tmp/SFS_Joint_test/10081/denoised/HCN1apo_0008_2xaligned.jpg'
# files = '/root/autodl-tmp/SFS_Joint_test/10028/denoised/061.jpg'
# 读取原来的图像
image = io.imread(files , as_gray=True)
# 标注的点数据
with open('/root/autodl-tmp/SFS_Joint_test/10081/points/HCN1apo_0008_2xaligned.json', 'r') as file:
# with open('/root/autodl-tmp/SFS_Joint_test/10028/points/061.json', 'r') as file:
    data = json.load(file)

# 绘制图像
plt.figure(figsize=(5, 5))
plt.imshow(image, cmap='gray')

# 标注点
x_coords = [point[0] for point in data]
y_coords = [point[1] for point in data]
plt.scatter(x_coords, y_coords, c='red', s=2, edgecolor='white')  # 红色点，带白色边框以增强可见性

EMPAIR={'10017':[4096,4096],  #wxh
        '10028':[4096,4096],
        '10081':[3710,3838],
        '10093':[3838,3710],
        '10345':[3838,3710],
        '10532':[4096,4096],
        '11056':[5760,4092]}

# 标注的点数据
with open('/root/Promptpoint/SFS_pro_Unet/datasets/test_dataset/10028/10028.json', 'r') as file:
    data = json.load(file)
    
data_points = data['062.csv']
original_width, original_height=EMPAIR['10028']

    # 计算缩放比例
scale_x =  original_width / 1024
scale_y =  original_height / 1024

# data是先x后y
restored_points = [(x / scale_x, y / scale_y) for x, y in data_points[0]]

# 标注点
x_coords = [point[0] for point in restored_points]
y_coords = [point[1] for point in restored_points]
# plt.scatter(x_coords, y_coords, c='blue', s=10, edgecolor='white')  # 红色点，带白色边框以增强可见性

plt.title("Image with Points")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from skimage import io
import json
import glob

files='/root/autodl-tmp/SFS_Joint_test/10081/pro_mask/HCN1apo_0008_2xaligned.jpg'
# 读取原来的图像
image = io.imread(files , as_gray=True)
# 标注的点数据
with open('/root/autodl-tmp/SFS_Joint_test/10081/points/HCN1apo_0008_2xaligned.json', 'r') as file:
    data = json.load(file)

# 绘制图像
plt.figure(figsize=(5, 5))
plt.imshow(image, cmap='gray')

# 标注点
x_coords = [point[0] for point in data]
y_coords = [point[1] for point in data]
plt.scatter(x_coords, y_coords, c='red', s=10, edgecolor='white')  # 红色点，带白色边框以增强可见性

EMPAIR={'10017':[4096,4096],  #wxh
        '10028':[4096,4096],
        '10081':[3710,3838],
        '10093':[3838,3710],
        '10345':[3838,3710],
        '10532':[4096,4096],
        '11056':[5760,4092]}

# 标注的点数据
with open('/root/Promptpoint/SFS_pro_Unet/datasets/test_dataset/10028/10028.json', 'r') as file:
    data = json.load(file)
    
data_points = data['062.csv']
original_width, original_height=EMPAIR['10028']

    # 计算缩放比例
scale_x =  original_width / 1024
scale_y =  original_height / 1024

# data是先x后y
restored_points = [(x / scale_x, y / scale_y) for x, y in data_points[0]]

# 标注点
x_coords = [point[0] for point in restored_points]
y_coords = [point[1] for point in restored_points]
# plt.scatter(x_coords, y_coords, c='blue', s=10, edgecolor='white')  # 红色点，带白色边框以增强可见性

plt.title("Image with Points")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from skimage import io
import json
import glob

files='/root/autodl-tmp/SFS_Joint_train_recall/10081/denoised/HCN1apo_0008_2xaligned.jpg'
# files= '/root/autodl-tmp/SFS_Joint_train_recall/10028/denoised/061.jpg'
# 读取原来的图像
image = io.imread(files , as_gray=True)
# 标注的点数据
with open('/root/autodl-tmp/SFS_Joint_train_recall/10081/points/HCN1apo_0008_2xaligned.json', 'r') as file:
# with open('/root/autodl-tmp/SFS_Joint_train_recall/10028/points/061.json', 'r') as file:
    data = json.load(file)

# 绘制图像
plt.figure(figsize=(5, 5))
plt.imshow(image, cmap='gray')

# 标注点
x_coords = [point[0] for point in data]
y_coords = [point[1] for point in data]
plt.scatter(x_coords, y_coords, c='red', s=2, edgecolor='white')  # 红色点，带白色边框以增强可见性

EMPAIR={'10017':[4096,4096],  #wxh
        '10028':[4096,4096],
        '10081':[3710,3838],
        '10093':[3838,3710],
        '10345':[3838,3710],
        '10532':[4096,4096],
        '11056':[5760,4092]}

# 标注的点数据
with open('/root/Promptpoint/SFS_pro_Unet/datasets/test_dataset/10028/10028.json', 'r') as file:
    data = json.load(file)
    
data_points = data['062.csv']
original_width, original_height=EMPAIR['10028']

    # 计算缩放比例
scale_x =  original_width / 1024
scale_y =  original_height / 1024

# data是先x后y
restored_points = [(x / scale_x, y / scale_y) for x, y in data_points[0]]

# 标注点
x_coords = [point[0] for point in restored_points]
y_coords = [point[1] for point in restored_points]
# plt.scatter(x_coords, y_coords, c='blue', s=10, edgecolor='white')  # 红色点，带白色边框以增强可见性

plt.title("Image with Points")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from skimage import io
import json
import glob

files='/root/autodl-tmp/SFS_Joint_train_recall/10081/pro_mask/HCN1apo_0008_2xaligned.jpg'
# 读取原来的图像
image = io.imread(files , as_gray=True)
# 标注的点数据
with open('/root/autodl-tmp/SFS_Joint_train_recall/10081/points/HCN1apo_0008_2xaligned.json', 'r') as file:
    data = json.load(file)

# 绘制图像
plt.figure(figsize=(5, 5))
plt.imshow(image, cmap='gray')

# 标注点
x_coords = [point[0] for point in data]
y_coords = [point[1] for point in data]
plt.scatter(x_coords, y_coords, c='red', s=10, edgecolor='white')  # 红色点，带白色边框以增强可见性

EMPAIR={'10017':[4096,4096],  #wxh
        '10028':[4096,4096],
        '10081':[3710,3838],
        '10093':[3838,3710],
        '10345':[3838,3710],
        '10532':[4096,4096],
        '11056':[5760,4092]}

# 标注的点数据
with open('/root/Promptpoint/SFS_pro_Unet/datasets/test_dataset/10028/10028.json', 'r') as file:
    data = json.load(file)
    
data_points = data['062.csv']
original_width, original_height=EMPAIR['10028']

    # 计算缩放比例
scale_x =  original_width / 1024
scale_y =  original_height / 1024

# data是先x后y
restored_points = [(x / scale_x, y / scale_y) for x, y in data_points[0]]

# 标注点
x_coords = [point[0] for point in restored_points]
y_coords = [point[1] for point in restored_points]
# plt.scatter(x_coords, y_coords, c='blue', s=10, edgecolor='white')  # 红色点，带白色边框以增强可见性

plt.title("Image with Points")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
